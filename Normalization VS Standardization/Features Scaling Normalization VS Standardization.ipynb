# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
df.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
scaling_data=df[['beer_servings', 'spirit_servings', 'wine_servings',
       'total_litres_of_pure_alcohol',]]

# %%
scaling_data.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normal_scaling=MinMaxScaler()

# %%
scaled_data=normal_scaling.fit_transform(scaling_data)

# %%
scaled_data
# Out:
# array([[0.        , 0.        , 0.        , 0.        ],
#        [0.23670213, 0.30136986, 0.14594595, 0.34027778],
#        [0.06648936, 0.        , 0.03783784, 0.04861111],
#        [0.65159574, 0.31506849, 0.84324324, 0.86111111],
#        [0.57712766, 0.13013699, 0.12162162, 0.40972222],
#        [0.2712766 , 0.29223744, 0.12162162, 0.34027778],
#        [0.51329787, 0.05707763, 0.5972973 , 0.57638889],
#        [0.05585106, 0.4086758 , 0.02972973, 0.26388889],
#        [0.69414894, 0.16438356, 0.57297297, 0.72222222],
#        [0.74202128, 0.17123288, 0.51621622, 0.67361111],
#        [0.05585106, 0.10502283, 0.01351351, 0.09027778],
#        [0.32446809, 0.40182648, 0.13783784, 0.4375    ],
#        [0.11170213, 0.14383562, 0.01891892, 0.13888889],
#        [0.        , 0.        , 0.        , 0.        ],
#        [0.38031915, 0.39497717, 0.0972973 , 0.4375    ],
#        [0.37765957, 0.85159817, 0.11351351, 1.        ],
# ...

# %% [markdown]
# # Satndardization Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
standard_scaler = StandardScaler()

# %%
scaled_data=standard_scaler.fit_transform(scaling_data)

# %%
scaled_data
# Out:
# array([[-1.05233793e+00, -9.19817653e-01, -6.22093877e-01,
#         -1.25337739e+00],
#        [-1.70108019e-01,  5.79240339e-01,  5.72295080e-02,
#          4.85986620e-02],
#        [-8.04520536e-01, -9.19817653e-01, -4.45973000e-01,
#         -1.06738081e+00],
#        [ 1.37627249e+00,  6.47379338e-01,  3.30288568e+00,
#          2.04141915e+00],
#        [ 1.09871701e+00, -2.72497156e-01, -5.59910562e-02,
#          3.14308060e-01],
#        [-4.12429769e-02,  5.33814339e-01, -5.59910562e-02,
#          4.85986620e-02],
#        [ 8.60812320e-01, -6.35905154e-01,  2.15809998e+00,
#          9.52010616e-01],
#        [-8.44171318e-01,  1.11299584e+00, -4.83713188e-01,
#         -2.43681676e-01],
#        [ 1.53487562e+00, -1.02149657e-01,  2.04487941e+00,
#          1.51000035e+00],
#        [ 1.71330414e+00, -6.80801576e-02,  1.78069810e+00,
#          1.32400377e+00],
#        [-8.44171318e-01, -3.97418656e-01, -5.59193564e-01,
#         -9.07955172e-01],
# ...
