# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.drop("Unnamed: 0",inplace=True,axis=1)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import seaborn as sns

# %%
sns.

# %%
sns.boxplot(y=df["sales"],data=df)

# %%
x=df["sales"]

# %%
xmean=x-x.mean()

# %%
xstd=x.std()
xstd
# Out:
# 5.217456565710477

# %%
zscore=xmean/xstd

# %%
zscore
# Out:
# 0      1.548168
# 1     -0.694304
# 2     -0.905135
# 3      0.858177
# 4     -0.215143
#          ...
# 195   -1.230964
# 196   -0.828469
# 197   -0.234310
# 198    2.199827
# 199   -0.119311
# Name: sales, Length: 200, dtype: float64

# %%
df["zscore"]=pd.DataFrame(zscore)

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales    zscore
# 0  230.1   37.8       69.2   22.1  1.548168
# 1   44.5   39.3       45.1   10.4 -0.694304
# 2   17.2   45.9       69.3    9.3 -0.905135
# 3  151.5   41.3       58.5   18.5  0.858177
# 4  180.8   10.8       58.4   12.9 -0.215143

# %%
(df["zscore"]>-2) & (df["zscore"]<2)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 195     True
# 196     True
# 197     True
# 198    False
# 199     True
# Name: zscore, Length: 200, dtype: bool

# %%
df[(df["zscore"]>-2) & (df["zscore"]<2)]
# Out:
#         TV  radio  newspaper  sales    zscore
# 0    230.1   37.8       69.2   22.1  1.548168
# 1     44.5   39.3       45.1   10.4 -0.694304
# 2     17.2   45.9       69.3    9.3 -0.905135
# 3    151.5   41.3       58.5   18.5  0.858177
# 4    180.8   10.8       58.4   12.9 -0.215143
# ..     ...    ...        ...    ...       ...
# 194  149.7   35.6        6.0   17.3  0.628180
# 195   38.2    3.7       13.8    7.6 -1.230964
# 196   94.2    4.9        8.1    9.7 -0.828469
# 197  177.0    9.3        6.4   12.8 -0.234310
# 199  232.1    8.6        8.7   13.4 -0.119311
#
# [191 rows x 5 columns]

# %%
191/200
# Out:
# 0.955

# %%
df[(df["zscore"]>-3) & (df["zscore"]<3)]
# Out:
#         TV  radio  newspaper  sales    zscore
# 0    230.1   37.8       69.2   22.1  1.548168
# 1     44.5   39.3       45.1   10.4 -0.694304
# 2     17.2   45.9       69.3    9.3 -0.905135
# 3    151.5   41.3       58.5   18.5  0.858177
# 4    180.8   10.8       58.4   12.9 -0.215143
# ..     ...    ...        ...    ...       ...
# 195   38.2    3.7       13.8    7.6 -1.230964
# 196   94.2    4.9        8.1    9.7 -0.828469
# 197  177.0    9.3        6.4   12.8 -0.234310
# 198  283.6   42.0       66.2   25.5  2.199827
# 199  232.1    8.6        8.7   13.4 -0.119311
#
# [200 rows x 5 columns]

# %%
df[(df["zscore"]>-1) & (df["zscore"]<1)]
# Out:
#         TV  radio  newspaper  sales    zscore
# 1     44.5   39.3       45.1   10.4 -0.694304
# 2     17.2   45.9       69.3    9.3 -0.905135
# 3    151.5   41.3       58.5   18.5  0.858177
# 4    180.8   10.8       58.4   12.9 -0.215143
# 6     57.5   32.8       23.5   11.8 -0.425974
# ..     ...    ...        ...    ...       ...
# 191   75.5   10.8        6.0    9.9 -0.790136
# 194  149.7   35.6        6.0   17.3  0.628180
# 196   94.2    4.9        8.1    9.7 -0.828469
# 197  177.0    9.3        6.4   12.8 -0.234310
# 199  232.1    8.6        8.7   13.4 -0.119311
#
# [134 rows x 5 columns]

# %%
134/200
# Out:
# 0.67

# %%
df_ho=df[(df["zscore"]>-1) & (df["zscore"]<1)]

# %%
df_ho
# Out:
#         TV  radio  newspaper  sales    zscore
# 1     44.5   39.3       45.1   10.4 -0.694304
# 2     17.2   45.9       69.3    9.3 -0.905135
# 3    151.5   41.3       58.5   18.5  0.858177
# 4    180.8   10.8       58.4   12.9 -0.215143
# 6     57.5   32.8       23.5   11.8 -0.425974
# ..     ...    ...        ...    ...       ...
# 191   75.5   10.8        6.0    9.9 -0.790136
# 194  149.7   35.6        6.0   17.3  0.628180
# 196   94.2    4.9        8.1    9.7 -0.828469
# 197  177.0    9.3        6.4   12.8 -0.234310
# 199  232.1    8.6        8.7   13.4 -0.119311
#
# [134 rows x 5 columns]
