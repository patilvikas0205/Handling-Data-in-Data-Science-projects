# %%
import numpy as np
import pandas as pd
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
LABELS = ["Normal", "Fraud"]

# %%
data=pd.read_csv("/content/drive/My Drive/Colab Notebooks/Handling Imbalance dataset/creditcard.csv")

# %%
data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
X=data.iloc[0:,0:30]
Y=data["Class"]

# %%
X.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
Y.shape
# Out:
# (284807,)

# %%
X.head()
# Out:
#    Time        V1        V2        V3  ...       V26       V27       V28  Amount
# 0   0.0 -1.359807 -0.072781  2.536347  ... -0.189115  0.133558 -0.021053  149.62
# 1   0.0  1.191857  0.266151  0.166480  ...  0.125895 -0.008983  0.014724    2.69
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.139097 -0.055353 -0.059752  378.66
# 3   1.0 -0.966272 -0.185226  1.792993  ... -0.221929  0.062723  0.061458  123.50
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.502292  0.219422  0.215153   69.99
#
# [5 rows x 30 columns]

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %%
X.shape, Y.shape
# Out:
# ((284807, 30), (284807,))

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(data['Class'], sort = True)

# %%
count_classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
count_classes=data["Class"].value_counts()
count_classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#Categorical data but in form of 0 and 1 so cant use seaborn
count_classes.plot(kind="bar", rot=0)
plt.title("Transaction class distribution")
plt.xlabel("Class")
plt.ylabel("requency")
plt.xticks(range(2),labels=LABELS)
#imbalance dataset
# Out:
# ([<matplotlib.axis.XTick at 0x7f85a215acc0>,
# ...
#  [Text(0, 0, 'Normal'), Text(0, 0, 'Fraud')])

# %%
normal=data[data["Class"]==0]
farud=data[data["Class"]==1]

# %%
normal.shape, farud.shape
# Out:
# ((284315, 31), (492, 31))

# %%
# Under Sampling
#from imblearn.under_sampling import NearMiss
#nm=NearMiss(random_state=42)
#X_res,Y_res=nm.fit_sample(X,Y)

# %%
#X_res.shape, Y_res.shape

# %%
from imblearn.combine import SMOTETomek
st=SMOTETomek(random_state=42)
X_res,Y_res=st.fit_sample(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
x_res.shape, Y_res.shape
# Out:
# ((567506, 30), (567562,))

# %%
from collections import Counter

# %%
print("Original data {}".format(Counter(Y)))
print("Resampled data {}".format(Counter(Y_res)))
# Out:
# Original data Counter({0: 284315, 1: 492})
# Resampled data Counter({0: 283781, 1: 283781})

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_res,Y_res)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((425671, 30), (141891, 30), (425671,), (141891,))

# %%
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(ratio=0.7)
X_res,Y_res=ros.fit_sample(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
x_res.shape, Y_res.shape
# Out:
# ((567506, 30), (568630,))

# %%
from collections import Counter
print("Original data: {}".format(Counter(Y)))
print("Resampling data: {}".format(Counter(Y_res)))
# Out:
# Original data: Counter({0: 284315, 1: 492})
# Resampling data: Counter({0: 284315, 1: 199020})

# %%
from imblearn.over_sampling import RandomOverSampler
ros=RandomOverSampler(ratio=1)
X_res,Y_res=ros.fit_sample(X,Y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
x_res.shape, Y_res.shape
# Out:
# ((567506, 30), (568630,))

# %%
from collections import Counter
print("Original data: {}".format(Counter(Y)))
print("Resampling data: {}".format(Counter(Y_res)))
# Out:
# Original data: Counter({0: 284315, 1: 492})
# Resampling data: Counter({0: 284315, 1: 284315})

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_res,Y_res)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((426472, 30), (142158, 30), (426472,), (142158,))
